# %%
# %load_ext autoreload
# %autoreload 2

# %%
def length(trajectory):
    return len(trajectory)

# %%
from framework import VehicleData

obj = VehicleData('./data.npy')

# %%
list_of_lats_lngs = obj.filter(length)

# %%
obj.plot(list_of_lats_lngs)
# Out:
# <module 'matplotlib.pyplot' from '/Users/reespawson/opt/anaconda3/envs/fastaiStableDiff/lib/python3.9/site-packages/matplotlib/pyplot.py'>
